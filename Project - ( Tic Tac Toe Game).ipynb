# %%
# !pip install TicTacToe3
# Out:
# ...
#      |████████████████████████████████| 296kB 12.4MB/s
# ...
#      |████████████████████████████████| 962kB 26.7MB/s
# ...

# %%
import TicTacToe3 as T3
T3.play()
# Out:
# Tic Tac Toe
# 3 in a Row
#
# -------------		Moves Commited : None
# |   |   |   |
# -------------
# |   |   |   |
# -------------
# |   |   |   |
# -------------
#
# Choose between 'X' or 'O' :x
#
# Your Move
# Enter the Row Number in which you would like to place X : 2
# Enter the Column Number in which you would like to place X : 2
# -------------		Moves Commited : 1
# |   |   |   |
# -------------
# |   | X |   |
# -------------
# |   |   |   |
# -------------
#
#
# My Move
# -------------		Moves Commited : 2
# |   |   |   |
# -------------
# |   | X |   |
# -------------
# |   | O |   |
# -------------
#
#
# Your Move
# Enter the Row Number in which you would like to place X : 1
# Enter the Column Number in which you would like to place X : 2
# -------------		Moves Commited : 3
# |   | X |   |
# -------------
# |   | X |   |
# -------------
# |   | O |   |
# -------------
#
#
# My Move
# -------------		Moves Commited : 4
# |   | X |   |
# -------------
# |   | X | O |
# ...
